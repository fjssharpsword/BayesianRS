# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(8,8))
for i in range(4): 
    if i==0:
        plt.subplot(2,2,i+1)#2行2列
        x= np.arange(1, 11, 1)
        ySVD = [1.2765,1.0288,0.9884,0.9687,0.9558,0.9978,0.9041,0.8787,0.8578,0.8422]
        yPMF = [1.2765,1.0288,0.9884,0.9687,0.9558,0.9978,0.9041,0.8787,0.8578,0.8422]
        yBLFM = [1.2765,1.0288,0.9884,0.9687,0.9558,0.9978,0.9041,0.8787,0.8578,0.8422]
        
        plt.plot(x,ySVD,"b",linewidth=2,marker='o',color='red',label='SVD')  
        plt.plot(x,yPMF,"b",linewidth=2,marker='o',color='green',label='PMF')
        plt.plot(x,yBLFM,"b",linewidth=2,marker='o',color='blue',label='BLFM')
        
        plt.xticks([index for index in x], x)
        #plt.xlabel('Iterations')
        plt.ylabel("RMSE")
        plt.title("Factor=8") #图标题
        plt.legend(loc = 'center')
    if i==1:
        plt.subplot(2,2,i+1)#2行2列
        x= np.arange(1, 11, 1)
        ySVD = [1.2765,1.0288,0.9884,0.9687,0.9558,0.9978,0.9041,0.8787,0.8578,0.8422]
        yPMF = [1.2765,1.0288,0.9884,0.9687,0.9558,0.9978,0.9041,0.8787,0.8578,0.8422]
        yBLFM = [1.2765,1.0288,0.9884,0.9687,0.9558,0.9978,0.9041,0.8787,0.8578,0.8422]
        
        plt.plot(x,ySVD,"b",linewidth=2,marker='o',color='red',label='SVD')  
        plt.plot(x,yPMF,"b",linewidth=2,marker='o',color='green',label='PMF')
        plt.plot(x,yBLFM,"b",linewidth=2,marker='o',color='blue',label='BLFM')
        
        plt.xticks([index for index in x], x)
        #plt.xlabel('Iterations')
        plt.ylabel("RMSE")
        plt.title("Factor=16") #图标题
        plt.legend(loc = 'center')
            
    if i==2:
        plt.subplot(2,2,i+1)#2行2列
        x= np.arange(1, 11, 1)
        ySVD = [1.2765,1.0288,0.9884,0.9687,0.9558,0.9978,0.9041,0.8787,0.8578,0.8422]
        yPMF = [1.2765,1.0288,0.9884,0.9687,0.9558,0.9978,0.9041,0.8787,0.8578,0.8422]
        yBLFM = [1.2765,1.0288,0.9884,0.9687,0.9558,0.9978,0.9041,0.8787,0.8578,0.8422]
        
        plt.plot(x,ySVD,"b",linewidth=2,marker='o',color='red',label='SVD')  
        plt.plot(x,yPMF,"b",linewidth=2,marker='o',color='green',label='PMF')
        plt.plot(x,yBLFM,"b",linewidth=2,marker='o',color='blue',label='BLFM')
        
        plt.xticks([index for index in x], x)
        plt.xlabel('Iterations')
        plt.ylabel("RMSE")
        plt.title("Factor=32") #图标题
        plt.legend(loc = 'center')
            
    if i==3:
        plt.subplot(2,2,i+1)#2行2列
        x= np.arange(1, 11, 1)
        ySVD = [1.2765,1.0288,0.9884,0.9687,0.9558,0.9978,0.9041,0.8787,0.8578,0.8422]
        yPMF = [1.2765,1.0288,0.9884,0.9687,0.9558,0.9978,0.9041,0.8787,0.8578,0.8422]
        yBLFM = [1.2765,1.0288,0.9884,0.9687,0.9558,0.9978,0.9041,0.8787,0.8578,0.8422]
        
        plt.plot(x,ySVD,"b",linewidth=2,marker='o',color='red',label='SVD')  
        plt.plot(x,yPMF,"b",linewidth=2,marker='o',color='green',label='PMF')
        plt.plot(x,yBLFM,"b",linewidth=2,marker='o',color='blue',label='BLFM')
        
        plt.xticks([index for index in x], x)
        plt.xlabel('Iterations')
        plt.ylabel("RMSE")
        plt.title("Factor=64") #图标题
        plt.legend(loc = 'center')

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10,4))
for i in range(4): 
    if i==0:
        plt.subplot(1,2,i+1)#2行2列
        x = [500, 1000, 2000, 3000, 4000, 5000]
        y5000 = [1.0354,1.0302, 1.0303, 1.0257, 1.0289, 1.0233]
        y10000 = [0.9893, 0.9873, 0.9855, 0.9839, 0.9829, 0.9837]
        y15000 = [0.9831, 0.9810, 0.9802, 0.9800, 0.9787, 0.9797]
        plt.plot(x,y5000,"b",linewidth=2,marker='o',color='blue',label='5000')  
        plt.plot(x,y10000,"b",linewidth=2,marker='o',color='red',label='10000')
        plt.plot(x,y15000,"b",linewidth=2,marker='o',color='green',label='15000')
        
        plt.xticks([index for index in x], x)
        plt.xlabel('Samples')
        plt.ylabel("RMSE")
        plt.title("BLFM") #图标题
        plt.legend(loc = 'center')
    if i==1:
        plt.subplot(1,2,i+1)#2行2列
        x = [500, 1000, 2000, 3000, 4000, 5000]
        y5000 = [0.9804, 0.9854, 0.9836, 0.9808, 0.9794, 0.9784]
        y10000 = [0.9555, 0.9533, 0.9510, 0.9499, 0.9505, 0.9492]
        y15000 = [0.9561, 0.9541, 0.9504, 0.9506, 0.9512, 0.9514]
        plt.plot(x,y5000,"b",linewidth=2,marker='o',color='blue',label='5000')  
        plt.plot(x,y10000,"b",linewidth=2,marker='o',color='red',label='10000')
        plt.plot(x,y15000,"b",linewidth=2,marker='o',color='green',label='15000')
        
        plt.xticks([index for index in x], x)
        plt.xlabel('Samples')
        #plt.ylabel("RMSE")
        plt.title("BLFMBias") #图标题
        plt.legend(loc = 'center')

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(8,8))
for i in range(4): 
    if i==0:
        plt.subplot(2,2,i+1)#2行2列
        x = ['SVD','PMF','BLFM']
        yt = [1.0249,1.0179,0.9781]
        yv = [0.9039,0.9262,0.9276]
        plt.vlines(0, 0.9039, 1.0249, colors = "r", linestyles = "dashed")
        plt.vlines(1, 0.9262, 1.0179, colors = "r", linestyles = "dashed")
        plt.vlines(2, 0.9276, 0.9781, colors = "r", linestyles = "dashed")
        plt.plot(x,yt,"b",linewidth=2,marker='o',color='blue',label='Test')  
        plt.plot(x,yv,"b",linewidth=2,marker='o',color='green',label='Train')
        
        plt.xticks([index for index in range(len(x))], x)
        #plt.xlabel('Models')
        plt.ylabel("RMSE")
        plt.title("Factors=8") #图标题
        plt.legend(loc = 'center')
    if i==1:
        plt.subplot(2,2,i+1)#2行2列
        x = ['SVD','PMF','BLFM']
        yt = [1.0222,1.0113,0.9836]
        yv = [0.8984,0.9250,0.9306]
        plt.vlines(0, 0.8984, 1.0222, colors = "r", linestyles = "dashed")
        plt.vlines(1, 0.9250, 1.0113, colors = "r", linestyles = "dashed")
        plt.vlines(2, 0.9306, 0.9836, colors = "r", linestyles = "dashed")
        plt.plot(x,yt,"b",linewidth=2,marker='o',color='blue',label='Test')  
        plt.plot(x,yv,"b",linewidth=2,marker='o',color='green',label='Train')
        
        plt.xticks([index for index in range(len(x))], x)
        #plt.xlabel('Models')
        #plt.ylabel("RMSE")
        plt.title("Factors=16") #图标题
        plt.legend(loc = 'center')
    if i==2:
        plt.subplot(2,2,i+1)#2行2列
        x = ['SVD','PMF','BLFM']
        yt = [1.0275,1.0003,0.9852]
        yv = [0.8991,0.9000,0.9337]
        plt.vlines(0, 0.8991, 1.0275, colors = "r", linestyles = "dashed")
        plt.vlines(1, 0.9000, 1.0003, colors = "r", linestyles = "dashed")
        plt.vlines(2, 0.9337, 0.9852, colors = "r", linestyles = "dashed")
        plt.plot(x,yt,"b",linewidth=2,marker='o',color='blue',label='Test')  
        plt.plot(x,yv,"b",linewidth=2,marker='o',color='green',label='Train')
        
        plt.xticks([index for index in range(len(x))], x)
        plt.xlabel('Models')
        plt.ylabel("RMSE")
        plt.title("Factors=32") #图标题
        plt.legend(loc = 'center')
    if i==3:
        plt.subplot(2,2,i+1)#2行2列
        x = ['SVD','PMF','BLFM']
        yt = [1.0252,0.9953,0.9826]
        yv = [0.9070,0.8982,0.9078]
        plt.vlines(0, 0.9070, 1.0252, colors = "r", linestyles = "dashed")
        plt.vlines(1, 0.8982, 0.9953, colors = "r", linestyles = "dashed")
        plt.vlines(2, 0.9078, 0.9826, colors = "r", linestyles = "dashed")
        plt.plot(x,yt,"b",linewidth=2,marker='o',color='blue',label='Test')  
        plt.plot(x,yv,"b",linewidth=2,marker='o',color='green',label='Train')
        
        plt.xticks([index for index in range(len(x))], x)
        plt.xlabel('Models')
        #plt.ylabel("RMSE")
        plt.title("Factors=64") #图标题
        plt.legend(loc = 'center')

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
for i in range(3): 
    if i==0:
        plt.subplot(3,1,i+1)#1行2列
        x = ['8','16','32','64']
        yt = [1.0249,1.0222,1.0275,1.0252]
        yv = [0.9039,0.8984,0.8991,0.9196]
        plt.plot(x,yt,"b",linewidth=2,marker='o',color='blue',label='Test')  
        plt.plot(x,yv,"b",linewidth=2,marker='o',color='red',label='Validation')  
        
        plt.xticks([index for index in x], x)
        plt.xlabel('Factors')
        plt.ylabel("RMSE")
        plt.title("SVD") #图标题
        plt.legend(loc = 'center')
    if i==1:
        plt.subplot(3,1,i+1)#1行2列
        x = ['8','16','32','64']
        yt = [1.0179,1.0113,1.0003,0.9953]
        yv = [0.9262,0.9250,0.9000,0.8982]
        plt.plot(x,yt,"b",linewidth=2,marker='o',color='blue',label='Test')  
        plt.plot(x,yv,"b",linewidth=2,marker='o',color='red',label='Validation')  
        
        plt.xticks([index for index in x], x)
        plt.xlabel('Factors')
        plt.ylabel("RMSE")
        plt.title("PMF") #图标题
        plt.legend(loc = 'center')
    if i==2:
        plt.subplot(3,1,i+1)#1行2列
        x = ['8','16','32','64']
        yt = [0.9781,0.9836,0.9852,0.9826]
        yv = [0.9276,0.9306,0.9337,0.9078] 
        plt.plot(x,yt,"b",linewidth=2,marker='o',color='blue',label='Test')  
        plt.plot(x,yv,"b",linewidth=2,marker='o',color='red',label='Validation')  
        
        plt.xticks([index for index in x], x)
        plt.xlabel('Factors')
        plt.ylabel("RMSE")
        plt.title("BMF") #图标题
        plt.legend(loc = 'center')

# %%
# coding:utf-8  
'''
@author: Jason.F
@data: 2019.08.12
@function: baseline: SVD 
           paper: https://dl.acm.org/citation.cfm?id=1401944
           Datatset: MovieLens-1m:https://grouplens.org/datasets/movielens/  
           Evaluation: RMSE
'''
import sys
import time
import logging
import random
import heapq
import math
from collections import defaultdict
import pymc3 as pm
import numpy as np
import pandas as pd
import theano
import theano.tensor as tt
import tensorflow as tf
from sklearn.model_selection import train_test_split

class DataSet:
    def __init__(self):
        self.trainset, self.testset, self.maxu, self.maxi, self.maxr = self._getDataset_as_list()
        
    def _getDataset_as_list(self):
        #trainset
        filePath = "/data/fjsdata/BMF/ml-1m.train.rating" 
        data = pd.read_csv(filePath, sep='\t', header=None, names=['user', 'item', 'rating'], \
                                 usecols=[0, 1, 2], dtype={0: np.int32, 1: np.int32, 2: np.float})
        maxu, maxi, maxr = data['user'].max()+1, data['item'].max()+1, data['rating'].max()
        print('Dataset Statistics: Interaction = %d, User = %d, Item = %d, Sparsity = %.4f' % \
                  (data.shape[0], maxu, maxi, data.shape[0]/(maxu*maxi)))     
        trainset = data.values.tolist()
        #testset
        filePath = "/data/fjsdata/BMF/ml-1m.test.rating" 
        data = pd.read_csv(filePath, sep='\t', header=None, names=['user', 'item', 'rating'], \
                                 usecols=[0, 1, 2], dtype={0: np.int32, 1: np.int32, 2: np.float})
        testset = data.values.tolist()
        return trainset, testset, maxu, maxi, maxr 
    
    def list_to_matrix(self, dataset, maxu, maxi):              
        dataMat = np.zeros([maxu, maxi], dtype=np.float32)
        for u,i,r in dataset:
            dataMat[int(u)][int(i)] = float(r)
        return np.array(dataMat)
    
class SVD():
    
    def __init__(self, R):
        """
        Perform matrix factorization to predict empty entries in a matrix.     
        Arguments
        - R (ndarray)   : user-item rating matrix
        - num_ng (int)  : number of negative items
        """
        self.R = R
        self.num_users, self.num_items = R.shape
        
        # Create a list of training samples
        self.samples = [
            (i, j, self.R[i, j])
            for i in range(self.num_users)
            for j in range(self.num_items)
            if self.R[i, j] > 0
        ]
        
    def train(self, K, alpha=0.001, beta=0.01, epochs=20):
        '''
        - alpha (float) : learning rate
        - beta (float)  : regularization parameter
        - K (int)       : number of latent dimensions
        -epochs(int)    : number of iterations
        '''
        self.K = K
        self.alpha = alpha
        self.beta = beta
        self.epochs = epochs
        # Initialize user and item latent feature matrice
        self.P = np.random.normal(scale=1./self.K, size=(self.num_users, self.K))
        self.Q = np.random.normal(scale=1./self.K, size=(self.num_items, self.K))
               
        # Perform stochastic gradient descent for number of iterations
        training_process = []
        for i in range(self.epochs):
            np.random.shuffle(self.samples)
            self.sgd()
            if (i+1) % 10 == 0:
                mse = self.mse()
                print("Iteration: %d ; error = %.4f" % (i+1, mse))
        
        return self.full_matrix()

    def mse(self):
        """
        A function to compute the total mean square error
        """
        xs, ys = self.R.nonzero()
        predicted = self.full_matrix()
        error = 0
        for x, y in zip(xs, ys):
            error += pow(self.R[x, y] - predicted[x, y], 2)
        return np.sqrt(error)

    def sgd(self):
        """
        Perform stochastic graident descent
        """
        for i, j, r in self.samples:
            # Computer prediction and error
            prediction = self.get_rating(i, j)
            e = (r - prediction)
            
            # Create copy of row of P since we need to update it but use older values for update on Q
            P_i = self.P[i, :][:]
            
            # Update user and item latent feature matrices
            self.P[i, :] += self.alpha * (e * self.Q[j, :] - self.beta * self.P[i,:])
            self.Q[j, :] += self.alpha * (e * P_i - self.beta * self.Q[j,:])

    def get_rating(self, i, j):
        """
        Get the predicted rating of user i and item j
        """
        prediction = self.P[i, :].dot(self.Q[j, :].T)
        return prediction
    
    def full_matrix(self):
        """
        Computer the full matrix using the resultant biases, P and Q
        """
        return self.P.dot(self.Q.T)
    
if __name__ == "__main__":
    ds = DataSet()#loading dataset
    svd = SVD(R=ds.list_to_matrix(ds.trainset,ds.maxu,ds.maxi))
    for K in [8, 16, 32, 64]:
        nR = svd.train(K=8, alpha=0.001, beta=0.01, epochs=20)
        squaredError = []
        for u,i,r in ds.testset:
            error=r - nR[int(u)][int(i)]
            squaredError.append(error * error)
        rmse =math.sqrt(sum(squaredError) / len(squaredError))
        print("RMSE@{}:{} of testset".format(K, rmse))
        valset = random.sample(ds.trainset, len(ds.testset))#get the same len of testset from trainset as validset.
        valError = []
        for u,i,r in valset:
            error=r - nR[int(u)][int(i)]
            valError.append(error * error)
        rmse =math.sqrt(sum(valError) / len(valError))
        print("RMSE@{}:{} of valset".format(K, rmse))
# Out:
# Dataset Statistics: Interaction = 994169, User = 6040, Item = 3706, Sparsity = 0.0444
# Iteration: 10 ; error = 998.4841
# Iteration: 20 ; error = 910.2249
# RMSE@8:1.0249474176177564 of testset
# RMSE@8:0.9039368686604249 of valset
# Iteration: 10 ; error = 1000.5919
# Iteration: 20 ; error = 906.2101
# RMSE@16:1.0222897884784823 of testset
# RMSE@16:0.8984013802847081 of valset
# Iteration: 10 ; error = 1004.8281
# Iteration: 20 ; error = 913.1759
# RMSE@32:1.027555577760309 of testset
# RMSE@32:0.8991240730504877 of valset
# Iteration: 10 ; error = 1000.6917
# Iteration: 20 ; error = 911.9363
# RMSE@64:1.025229061978943 of testset
# RMSE@64:0.9196815342415844 of valset

# %%
# coding:utf-8  
'''
@author: Jason.F
@data: 2019.08.12
@function: baseline: SVD 
           paper: https://dl.acm.org/citation.cfm?id=1401944
           Datatset: MovieLens-1m:https://grouplens.org/datasets/movielens/  
           Evaluation: RMSE
'''
import sys
import time
import logging
import random
import heapq
import math
from collections import defaultdict
import pymc3 as pm
import numpy as np
import pandas as pd
import theano
import theano.tensor as tt
import tensorflow as tf
from sklearn.model_selection import train_test_split

class DataSet:
    def __init__(self):
        self.trainset, self.testset, self.maxu, self.maxi, self.maxr = self._getDataset_as_list()
        
    def _getDataset_as_list(self):
        #trainset
        filePath = "/data/fjsdata/BMF/ml-1m.train.rating" 
        data = pd.read_csv(filePath, sep='\t', header=None, names=['user', 'item', 'rating'], \
                                 usecols=[0, 1, 2], dtype={0: np.int32, 1: np.int32, 2: np.float})
        maxu, maxi, maxr = data['user'].max()+1, data['item'].max()+1, data['rating'].max()
        print('Dataset Statistics: Interaction = %d, User = %d, Item = %d, Sparsity = %.4f' % \
                  (data.shape[0], maxu, maxi, data.shape[0]/(maxu*maxi)))     
        trainset = data.values.tolist()
        #testset
        filePath = "/data/fjsdata/BMF/ml-1m.test.rating" 
        data = pd.read_csv(filePath, sep='\t', header=None, names=['user', 'item', 'rating'], \
                                 usecols=[0, 1, 2], dtype={0: np.int32, 1: np.int32, 2: np.float})
        testset = data.values.tolist()
        return trainset, testset, maxu, maxi, maxr 
    
    def list_to_matrix(self, dataset, maxu, maxi):              
        dataMat = np.zeros([maxu, maxi], dtype=np.float32)
        for u,i,r in dataset:
            dataMat[int(u)][int(i)] = float(r)
        return np.array(dataMat)
    
class SVD():
    
    def __init__(self, R):
        """
        Perform matrix factorization to predict empty entries in a matrix.     
        Arguments
        - R (ndarray)   : user-item rating matrix
        - num_ng (int)  : number of negative items
        """
        self.R = R
        self.num_users, self.num_items = R.shape
        
        # Create a list of training samples
        self.samples = [
            (i, j, self.R[i, j])
            for i in range(self.num_users)
            for j in range(self.num_items)
            if self.R[i, j] > 0
        ]
        
    def train(self, K, alpha=0.001, beta=0.01, epochs=20):
        '''
        - alpha (float) : learning rate
        - beta (float)  : regularization parameter
        - K (int)       : number of latent dimensions
        -epochs(int)    : number of iterations
        '''
        self.K = K
        self.alpha = alpha
        self.beta = beta
        self.epochs = epochs
        # Initialize user and item latent feature matrice
        self.P = np.random.normal(scale=1./self.K, size=(self.num_users, self.K))
        self.Q = np.random.normal(scale=1./self.K, size=(self.num_items, self.K))
               
        # Perform stochastic gradient descent for number of iterations
        training_process = []
        for i in range(self.epochs):
            np.random.shuffle(self.samples)
            self.sgd()
            if (i+1) % 10 == 0:
                mse = self.mse()
                print("Iteration: %d ; error = %.4f" % (i+1, mse))
        
        return self.full_matrix()

    def mse(self):
        """
        A function to compute the total mean square error
        """
        xs, ys = self.R.nonzero()
        predicted = self.full_matrix()
        error = 0
        for x, y in zip(xs, ys):
            error += pow(self.R[x, y] - predicted[x, y], 2)
        return np.sqrt(error)

    def sgd(self):
        """
        Perform stochastic graident descent
        """
        for i, j, r in self.samples:
            # Computer prediction and error
            prediction = self.get_rating(i, j)
            e = (r - prediction)
            
            # Create copy of row of P since we need to update it but use older values for update on Q
            P_i = self.P[i, :][:]
            
            # Update user and item latent feature matrices
            self.P[i, :] += self.alpha * (e * self.Q[j, :] - self.beta * self.P[i,:])
            self.Q[j, :] += self.alpha * (e * P_i - self.beta * self.Q[j,:])

    def get_rating(self, i, j):
        """
        Get the predicted rating of user i and item j
        """
        prediction = self.P[i, :].dot(self.Q[j, :].T)
        return prediction
    
    def full_matrix(self):
        """
        Computer the full matrix using the resultant biases, P and Q
        """
        return self.P.dot(self.Q.T)
    
if __name__ == "__main__":
    ds = DataSet()#loading dataset
    svd = SVD(R=ds.list_to_matrix(ds.trainset,ds.maxu,ds.maxi))
    for beta in [0.1, 0.05, 0.001, 0.0005]:
        nR = svd.train(K=8, alpha=0.001, beta=0.01, epochs=20)
        squaredError = []
        for u,i,r in ds.testset:
            error=r - nR[int(u)][int(i)]
            squaredError.append(error * error)
        rmse =math.sqrt(sum(squaredError) / len(squaredError))
        print("RMSE@{}:{} of testset".format(beta, rmse))
        valset = random.sample(ds.trainset, len(ds.testset))#get the same len of testset from trainset as validset.
        valError = []
        for u,i,r in valset:
            error=r - nR[int(u)][int(i)]
            valError.append(error * error)
        rmse =math.sqrt(sum(valError) / len(valError))
        print("RMSE@{}:{} of valset".format(beta, rmse))
# Out:
# Dataset Statistics: Interaction = 994169, User = 6040, Item = 3706, Sparsity = 0.0444
# Iteration: 10 ; error = 1002.5372
# Iteration: 20 ; error = 911.6839
# RMSE@0.1:1.0270293858367587 of testset
# RMSE@0.1:0.913648857059958 of valset
# Iteration: 10 ; error = 997.0021
# Iteration: 20 ; error = 913.9429
# RMSE@0.05:1.0257975162977422 of testset
# RMSE@0.05:0.9088017290189427 of valset
# Iteration: 10 ; error = 1003.0626
# Iteration: 20 ; error = 913.3142
# RMSE@0.001:1.026329068311539 of testset
# RMSE@0.001:0.9151931266349349 of valset
# Iteration: 10 ; error = 1000.9222
# Iteration: 20 ; error = 910.9012
# RMSE@0.0005:1.0268740306067672 of testset
# RMSE@0.0005:0.8976276658726724 of valset

# %%
import numpy as np
import pandas as pd

filePath = "/data/fjsdata/BMF/ml-1m.train.rating" 
data = pd.read_csv(filePath, sep='\t', header=None, names=['user', 'item', 'rating'], \
                                usecols=[0, 1, 2], dtype={0: np.int32, 1: np.int32, 2: np.float})
maxu, maxi, maxr = data['user'].max()+1, data['item'].max()+1, data['rating'].max()
print('Dataset Statistics: Interaction = %d, User = %d, Item = %d, Sparsity = %.4f' % \
                  (data.shape[0], maxu, maxi, data.shape[0]/(maxu*maxi)))
rs = pd.DataFrame([data.mean(), data.std(), data.var()], index=['Mean', 'Std. dev', 'Variance'])
print (rs)
# Out:
# Dataset Statistics: Interaction = 994169, User = 6040, Item = 3706, Sparsity = 0.0444
#                   user           item    rating
# Mean      3.023537e+03     872.860828  3.581378
# Std. dev  1.728320e+03     738.213243  1.116791
# Variance  2.987090e+06  544958.792605  1.247222

# %%
import numpy as np
import pandas as pd

filePath = "/data/fjsdata/BMF/kbcc_trainset.csv" 
data = pd.read_csv(filePath, sep='|', low_memory=False, dtype={'csr':int, 'ke':int, 'num':float})
maxu, maxi, maxr = data['csr'].max()+1, data['ke'].max()+1, data['num'].max()
print('Dataset Statistics: Interaction = %d, User = %d, Item = %d, Sparsity = %.4f' % \
                  (data.shape[0], maxu, maxi, data.shape[0]/(maxu*maxi)))
rs = pd.DataFrame([data.mean(), data.std(), data.var()], index=['Mean', 'Std. dev', 'Variance'])
print (rs)
# Out:
# Dataset Statistics: Interaction = 2313189, User = 10216, Item = 96324, Sparsity = 0.0024
#                    csr            ke       num
# Mean      4.788496e+03  5.249678e+04  2.208648
# Std. dev  2.657450e+03  2.589617e+04  1.961752
# Variance  7.062041e+06  6.706117e+08  3.848470
